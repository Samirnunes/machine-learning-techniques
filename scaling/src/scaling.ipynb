# %% [markdown]
# ## Machine Learning Tecniques: Scaling

# %% [markdown]
# ### Libraries, data and preprocessing

# %%
from churn_modelling_utils import (
    import_data, 
    preprocess_without_scale, 
    num_cat_cols
)

# %%
df = import_data()
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10002 non-null  int64
#  1   Geography        10001 non-null  object
#  2   Gender           10002 non-null  object
#  3   Age              10001 non-null  float64
#  4   Tenure           10002 non-null  int64
#  5   Balance          10002 non-null  float64
#  6   NumOfProducts    10002 non-null  int64
#  7   HasCrCard        10001 non-null  float64
#  8   IsActiveMember   10001 non-null  float64
#  9   EstimatedSalary  10002 non-null  float64
#  10  Exited           10002 non-null  int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 859.7+ KB
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.0       2       0.00              1
# 1          608     Spain  Female  41.0       1   83807.86              1
# 2          502    France  Female  42.0       8  159660.80              3
# 3          699    France  Female  39.0       1       0.00              2
# 4          850     Spain  Female  43.0       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             1.0        101348.88       1
# 1        0.0             1.0        112542.58       0
# 2        1.0             0.0        113931.57       1
# 3        0.0             0.0         93826.63       0
# 4        NaN             1.0         79084.10       0

# %%
X_train, X_test, y_train, y_test = preprocess_without_scale(df)

# %% [markdown]
# #### Data before scaling

# %%
X_train.head()
# Out:
#   CreditScore   Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# 0         619  42.0      2        0.0             1       1.0            1.0
# 1         608  41.0      1   83807.86             1       0.0            1.0
# 2         502  42.0      8   159660.8             3       1.0            0.0
# 3         699  39.0      1        0.0             2       0.0            0.0
# 4         850  43.0      2  125510.82             1       1.0            1.0
#
#   EstimatedSalary  Geography_France  Geography_Germany  Geography_Spain  \
# 0       101348.88              True              False            False
# 1       112542.58             False              False             True
# 2       113931.57              True              False            False
# 3        93826.63              True              False            False
# 4         79084.1             False              False             True
#
#    Gender_Female  Gender_Male
# 0           True        False
# 1           True        False
# 2           True        False
# 3           True        False
# 4           True        False

# %%
X_test.head()
# Out:
#   CreditScore   Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# 0         707  32.0      9        0.0             2       1.0            0.0
# 1         590  37.0      1        0.0             2       0.0            0.0
# 2         603  57.0      6  105000.85             2       1.0            1.0
# 3         615  45.0      5        0.0             2       1.0            1.0
# 4         634  36.0      1   69518.95             1       1.0            0.0
#
#   EstimatedSalary  Geography_France  Geography_Germany  Geography_Spain  \
# 0       126475.79             False              False             True
# 1       133535.99             False              False             True
# 2        87412.24             False              False             True
# 3       164886.64              True              False            False
# 4       116238.39              True              False            False
#
#    Gender_Female  Gender_Male
# 0          False         True
# 1          False         True
# 2          False         True
# 3          False         True
# 4           True        False

# %% [markdown]
# ### Scaling

# %%
from scaler import Scaler

# %%
num_cols, _ = num_cat_cols(X_train)

# %% [markdown]
# #### MinMaxScale

# %% [markdown]
# $$x_{i,scaled} = \frac{x_{i} - x_{min}}{x_{max} - x_{min}}$$

# %%
scaler = Scaler("minmax")
X_train_min_max, X_test_min_max = scaler.scale(X_train, X_test, num_cols)

# %%
X_train_min_max[num_cols].head()
# Out:
#     Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0  0.000000       0.000000              0.0  0.324324                0.0
# 1  0.334031       0.000000              1.0  0.310811                0.0
# 2  0.636357       0.666667              0.0  0.324324                0.0
# 3  0.000000       0.333333              0.0  0.283784                0.0
# 4  0.500246       0.000000              1.0  0.337838                0.0
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0        1.0            1.0         0.506735          0.0             1.0
# 1        0.0            1.0         0.562709          0.0             1.0
# 2        1.0            1.0         0.569654          0.0             0.0
# 3        0.0            1.0         0.469120          0.0             0.0
# 4        1.0            1.0         0.395400          0.0             1.0
#
#    CreditScore  Tenure  Geography_France
# 0        0.538     0.2               1.0
# 1        0.516     0.1               0.0
# 2        0.304     0.8               1.0
# 3        0.698     0.1               1.0
# 4        1.000     0.2               0.0

# %%
X_test_min_max[num_cols].head()
# Out:
#    Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0  0.00000       0.333333              1.0  0.189189                0.0
# 1  0.00000       0.333333              1.0  0.256757                0.0
# 2  0.41850       0.333333              1.0  0.527027                0.0
# 3  0.00000       0.333333              0.0  0.364865                0.0
# 4  0.27708       0.000000              0.0  0.243243                0.0
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0        1.0            0.0         0.632381          1.0             0.0
# 1        0.0            0.0         0.667686          1.0             0.0
# 2        1.0            0.0         0.437045          1.0             1.0
# 3        1.0            0.0         0.824454          1.0             1.0
# 4        1.0            1.0         0.581190          0.0             0.0
#
#    CreditScore  Tenure  Geography_France
# 0        0.714     0.9               0.0
# 1        0.480     0.1               0.0
# 2        0.506     0.6               0.0
# 3        0.530     0.5               1.0
# 4        0.568     0.1               1.0

# %% [markdown]
# #### StandardScale

# %% [markdown]
# $$x_{i,scaled} = \frac{x_{i} - \bar{x}}{s_{x}}$$

# %%
scaler = Scaler("standard")
X_train_std, X_test_std = scaler.scale(X_train, X_test, num_cols)

# %%
X_train_std[num_cols].head()
# Out:
#     Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0 -1.231136      -0.905678        -0.576340  0.291282          -0.576532
# 1  0.112282      -0.905678         1.735087  0.196126          -0.576532
# 2  1.328184       2.524539        -0.576340  0.291282          -0.576532
# 3 -1.231136       0.809430        -0.576340  0.005815          -0.576532
# 4  0.780769      -0.905678         1.735087  0.386437          -0.576532
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0   0.652064       1.089889         0.019822    -1.089889        0.974942
# 1  -1.533593       1.089889         0.214414    -1.089889        0.974942
# 2   0.652064       1.089889         0.238561    -1.089889       -1.025702
# 3  -1.533593       1.089889        -0.110946    -1.089889       -1.025702
# 4   0.652064       1.089889        -0.367231    -1.089889        0.974942
#
#    CreditScore    Tenure  Geography_France
# 0    -0.322101 -1.044697          0.997628
# 1    -0.435693 -1.391412         -1.002378
# 2    -1.530301  1.035596          0.997628
# 3     0.504019 -1.391412          0.997628
# 4     2.063320 -1.044697         -1.002378

# %%
X_test_std[num_cols].head()
# Out:
#     Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0 -1.231136       0.809430         1.735087 -0.660273          -0.576532
# 1 -1.231136       0.809430         1.735087 -0.184496          -0.576532
# 2  0.452000       0.809430         1.735087  1.718614          -0.576532
# 3 -1.231136       0.809430        -0.576340  0.576748          -0.576532
# 4 -0.116766      -0.905678        -0.576340 -0.279651          -0.576532
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0   0.652064      -0.917524         0.456630     0.917524       -1.025702
# 1  -1.533593      -0.917524         0.579366     0.917524       -1.025702
# 2   0.652064      -0.917524        -0.222454     0.917524        0.974942
# 3   0.652064      -0.917524         1.124368     0.917524        0.974942
# 4   0.652064       1.089889         0.278663    -1.089889       -1.025702
#
#    CreditScore    Tenure  Geography_France
# 0     0.586630  1.382312         -1.002378
# 1    -0.621570 -1.391412         -1.002378
# 2    -0.487325  0.342165         -1.002378
# 3    -0.363407 -0.004550          0.997628
# 4    -0.167204 -1.391412          0.997628

# %% [markdown]
# #### RobustScale

# %% [markdown]
# $$x_{i,scaled} = \frac{x_{i} - x_{median}}{IQR}$$
#
# IQR = 3rd quartile - 1st quartile = 75th quantile - 25th quantile

# %%
scaler = Scaler("robust")
X_train_robust, X_test_robust = scaler.scale(X_train, X_test, num_cols)

# %%
X_train_robust[num_cols].head()
# Out:
#     Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0 -0.764044            0.0         0.000000  0.416667                0.0
# 1 -0.108394            0.0         2.311427  0.333333                0.0
# 2  0.485024            2.0         0.000000  0.416667                0.0
# 3 -0.764044            1.0         0.000000  0.166667                0.0
# 4  0.217860            0.0         2.311427  0.500000                0.0
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0        0.0            1.0         0.010650         -1.0             0.0
# 1       -1.0            1.0         0.124760         -1.0             0.0
# 2        0.0            1.0         0.138920         -1.0            -1.0
# 3       -1.0            1.0        -0.066032         -1.0            -1.0
# 4        0.0            1.0        -0.216319         -1.0             0.0
#
#    CreditScore  Tenure  Geography_France
# 0    -0.238806   -0.75               0.0
# 1    -0.320896   -1.00              -1.0
# 2    -1.111940    0.75               0.0
# 3     0.358209   -1.00               0.0
# 4     1.485075   -0.75              -1.0

# %%
X_test_robust[num_cols].head()
# Out:
#     Balance  NumOfProducts  Geography_Spain       Age  Geography_Germany  \
# 0 -0.764044            1.0         2.311427 -0.416667                0.0
# 1 -0.764044            1.0         2.311427  0.000000                0.0
# 2  0.057405            1.0         2.311427  1.666667                0.0
# 3 -0.764044            1.0         0.000000  0.666667                0.0
# 4 -0.220180            0.0         0.000000 -0.083333                0.0
#
#    HasCrCard  Gender_Female  EstimatedSalary  Gender_Male  IsActiveMember  \
# 0        0.0            0.0         0.266797          0.0            -1.0
# 1       -1.0            0.0         0.338769          0.0            -1.0
# 2        0.0            0.0        -0.131421          0.0             0.0
# 3        0.0            0.0         0.658361          0.0             0.0
# 4        0.0            1.0         0.162436         -1.0            -1.0
#
#    CreditScore  Tenure  Geography_France
# 0     0.417910    1.00              -1.0
# 1    -0.455224   -1.00              -1.0
# 2    -0.358209    0.25              -1.0
# 3    -0.268657    0.00               0.0
# 4    -0.126866   -1.00               0.0
